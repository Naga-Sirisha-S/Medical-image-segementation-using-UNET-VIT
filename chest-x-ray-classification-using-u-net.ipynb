# 2  /kaggle/input/chest-x-ray-dataset-4-categories...  COVID19
# 3  /kaggle/input/chest-x-ray-dataset-4-categories...  COVID19
# 4  /kaggle/input/chest-x-ray-dataset-4-categories...  COVID19

# %%
df.tail()
# Out:
#                                              image_path       category
# 7127  /kaggle/input/chest-x-ray-dataset-4-categories...  TURBERCULOSIS
# 7128  /kaggle/input/chest-x-ray-dataset-4-categories...  TURBERCULOSIS
# 7129  /kaggle/input/chest-x-ray-dataset-4-categories...  TURBERCULOSIS
# 7130  /kaggle/input/chest-x-ray-dataset-4-categories...  TURBERCULOSIS
# 7131  /kaggle/input/chest-x-ray-dataset-4-categories...  TURBERCULOSIS

# %%
df.shape
# Out:
# (7132, 2)

# %%
df.columns
# Out:
# Index(['image_path', 'category'], dtype='object')

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# image_path    0
# category      0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7132 entries, 0 to 7131
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   image_path  7132 non-null   object
#  1   category    7132 non-null   object
# dtypes: object(2)
# memory usage: 111.6+ KB

# %%
df['category'].unique()
# Out:
# array(['COVID19', 'NORMAL', 'PNEUMONIA', 'TURBERCULOSIS'], dtype=object)

# %%
df['category'].value_counts()
# Out:
# category
# PNEUMONIA        4273
# NORMAL           1583
# TURBERCULOSIS     700
# COVID19           576
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

category_counts = df['category'].value_counts()

plt.figure(figsize=(8, 6))
sns.barplot(x=category_counts.index, y=category_counts.values, palette="viridis")
plt.title("Count of Images per Category")
plt.xlabel("Category")
plt.ylabel("Number of Images")
plt.show()

plt.figure(figsize=(8, 6))
plt.pie(category_counts.values, labels=category_counts.index, autopct='%1.1f%%', startangle=140, colors=sns.color_palette("viridis", len(category_counts)))
plt.title("Proportion of Images per Category")
plt.show()

# %%
import random
from PIL import Image

num_images_per_category = 5

plt.figure(figsize=(15, 10))

for i, category in enumerate(df['category'].unique()):

    category_images = df[df['category'] == category]['image_path']
    
    selected_images = random.sample(list(category_images), num_images_per_category)
    
    for j, image_path in enumerate(selected_images):

        img = Image.open(image_path)
        
        plt.subplot(len(df['category'].unique()), num_images_per_category, i * num_images_per_category + j + 1)
        plt.imshow(img, cmap='gray')
        plt.axis('off')
        plt.title(category if j == 0 else "") 

plt.tight_layout()
plt.show()

# %%
def encoder_block(inputs, num_filters): 

	x = tf.keras.layers.Conv2D(num_filters, 
							3, 
							padding = 'valid')(inputs) 
	x = tf.keras.layers.Activation('relu')(x) 
	
	x = tf.keras.layers.Conv2D(num_filters, 
							3, 
							padding = 'valid')(x) 
	x = tf.keras.layers.Activation('relu')(x) 

	x = tf.keras.layers.MaxPool2D(pool_size = (2, 2), 
								strides = 2)(x) 
	
	return x

# %%
from tensorflow.keras.layers import Lambda

def decoder_block(inputs, skip_features, num_filters): 
   
    x = tf.keras.layers.Conv2DTranspose(num_filters, 
                                        (2, 2), 
                                        strides = 2, 
                                        padding = 'valid')(inputs) 
    
   
    x = Lambda(lambda x: tf.image.resize(x, size=(skip_features.shape[1], skip_features.shape[2])))(x)

    x = tf.keras.layers.Concatenate()([x, skip_features]) 
    
    x = tf.keras.layers.Conv2D(num_filters, 3, padding = 'valid')(x) 
    x = tf.keras.layers.Activation('relu')(x) 

    x = tf.keras.layers.Conv2D(num_filters, 3, padding = 'valid')(x) 
    x = tf.keras.layers.Activation('relu')(x) 
    
    return x

# %%
import tensorflow as tf 

def unet_model(input_shape = (256, 256, 3), num_classes = 2): 
	inputs = tf.keras.layers.Input(input_shape) 
	
	s1 = encoder_block(inputs, 64) 
	s2 = encoder_block(s1, 128) 
	s3 = encoder_block(s2, 256) 
	s4 = encoder_block(s3, 512) 
	
	b1 = tf.keras.layers.Conv2D(1024, 3, padding = 'valid')(s4) 
	b1 = tf.keras.layers.Activation('relu')(b1) 
	b1 = tf.keras.layers.Conv2D(1024, 3, padding = 'valid')(b1) 
	b1 = tf.keras.layers.Activation('relu')(b1) 
	
	s5 = decoder_block(b1, s4, 512) 
	s6 = decoder_block(s5, s3, 256) 
	s7 = decoder_block(s6, s2, 128) 
	s8 = decoder_block(s7, s1, 64) 
	
	outputs = tf.keras.layers.Conv2D(num_classes, 
									1, 
									padding = 'valid', 
									activation = 'sigmoid')(s8) 
	
	model = tf.keras.models.Model(inputs = inputs, 
								outputs = outputs, 
								name = 'U-Net') 
	return model 

if __name__ == '__main__': 
	model = unet_model(input_shape=(572, 572, 3), num_classes=2) 
	model.summary()
# Out:
# Model: "U-Net"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)  │ (None, 572, 572, 3)    │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d (Conv2D)           │ (None, 570, 570, 64)   │          1,792 │ input_layer[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation (Activation)   │ (None, 570, 570, 64)   │              0 │ conv2d[0][0]           │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_1 (Conv2D)         │ (None, 568, 568, 64)   │         36,928 │ activation[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_1 (Activation) │ (None, 568, 568, 64)   │              0 │ conv2d_1[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d             │ (None, 284, 284, 64)   │              0 │ activation_1[0][0]     │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_2 (Conv2D)         │ (None, 282, 282, 128)  │         73,856 │ max_pooling2d[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_2 (Activation) │ (None, 282, 282, 128)  │              0 │ conv2d_2[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_3 (Conv2D)         │ (None, 280, 280, 128)  │        147,584 │ activation_2[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_3 (Activation) │ (None, 280, 280, 128)  │              0 │ conv2d_3[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_1           │ (None, 140, 140, 128)  │              0 │ activation_3[0][0]     │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_4 (Conv2D)         │ (None, 138, 138, 256)  │        295,168 │ max_pooling2d_1[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_4 (Activation) │ (None, 138, 138, 256)  │              0 │ conv2d_4[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_5 (Conv2D)         │ (None, 136, 136, 256)  │        590,080 │ activation_4[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_5 (Activation) │ (None, 136, 136, 256)  │              0 │ conv2d_5[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_2           │ (None, 68, 68, 256)    │              0 │ activation_5[0][0]     │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_6 (Conv2D)         │ (None, 66, 66, 512)    │      1,180,160 │ max_pooling2d_2[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_6 (Activation) │ (None, 66, 66, 512)    │              0 │ conv2d_6[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_7 (Conv2D)         │ (None, 64, 64, 512)    │      2,359,808 │ activation_6[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_7 (Activation) │ (None, 64, 64, 512)    │              0 │ conv2d_7[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_3           │ (None, 32, 32, 512)    │              0 │ activation_7[0][0]     │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_8 (Conv2D)         │ (None, 30, 30, 1024)   │      4,719,616 │ max_pooling2d_3[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_8 (Activation) │ (None, 30, 30, 1024)   │              0 │ conv2d_8[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_9 (Conv2D)         │ (None, 28, 28, 1024)   │      9,438,208 │ activation_8[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_9 (Activation) │ (None, 28, 28, 1024)   │              0 │ conv2d_9[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose          │ (None, 56, 56, 512)    │      2,097,664 │ activation_9[0][0]     │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lambda (Lambda)           │ (None, 32, 32, 512)    │              0 │ conv2d_transpose[0][0] │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate (Concatenate) │ (None, 32, 32, 1024)   │              0 │ lambda[0][0],          │
# │                           │                        │                │ max_pooling2d_3[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_10 (Conv2D)        │ (None, 30, 30, 512)    │      4,719,104 │ concatenate[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_10             │ (None, 30, 30, 512)    │              0 │ conv2d_10[0][0]        │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_11 (Conv2D)        │ (None, 28, 28, 512)    │      2,359,808 │ activation_10[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_11             │ (None, 28, 28, 512)    │              0 │ conv2d_11[0][0]        │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose_1        │ (None, 56, 56, 256)    │        524,544 │ activation_11[0][0]    │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lambda_1 (Lambda)         │ (None, 68, 68, 256)    │              0 │ conv2d_transpose_1[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_1             │ (None, 68, 68, 512)    │              0 │ lambda_1[0][0],        │
# │ (Concatenate)             │                        │                │ max_pooling2d_2[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_12 (Conv2D)        │ (None, 66, 66, 256)    │      1,179,904 │ concatenate_1[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_12             │ (None, 66, 66, 256)    │              0 │ conv2d_12[0][0]        │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_13 (Conv2D)        │ (None, 64, 64, 256)    │        590,080 │ activation_12[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_13             │ (None, 64, 64, 256)    │              0 │ conv2d_13[0][0]        │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose_2        │ (None, 128, 128, 128)  │        131,200 │ activation_13[0][0]    │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lambda_2 (Lambda)         │ (None, 140, 140, 128)  │              0 │ conv2d_transpose_2[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_2             │ (None, 140, 140, 256)  │              0 │ lambda_2[0][0],        │
# │ (Concatenate)             │                        │                │ max_pooling2d_1[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_14 (Conv2D)        │ (None, 138, 138, 128)  │        295,040 │ concatenate_2[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_14             │ (None, 138, 138, 128)  │              0 │ conv2d_14[0][0]        │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_15 (Conv2D)        │ (None, 136, 136, 128)  │        147,584 │ activation_14[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_15             │ (None, 136, 136, 128)  │              0 │ conv2d_15[0][0]        │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose_3        │ (None, 272, 272, 64)   │         32,832 │ activation_15[0][0]    │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lambda_3 (Lambda)         │ (None, 284, 284, 64)   │              0 │ conv2d_transpose_3[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_3             │ (None, 284, 284, 128)  │              0 │ lambda_3[0][0],        │
# │ (Concatenate)             │                        │                │ max_pooling2d[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_16 (Conv2D)        │ (None, 282, 282, 64)   │         73,792 │ concatenate_3[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_16             │ (None, 282, 282, 64)   │              0 │ conv2d_16[0][0]        │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_17 (Conv2D)        │ (None, 280, 280, 64)   │         36,928 │ activation_16[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_17             │ (None, 280, 280, 64)   │              0 │ conv2d_17[0][0]        │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_18 (Conv2D)        │ (None, 280, 280, 2)    │            130 │ activation_17[0][0]    │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 31,031,810 (118.38 MB)
#  Trainable params: 31,031,810 (118.38 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
import numpy as np 
from PIL import Image 
from tensorflow.keras.preprocessing import image 
 
img = Image.open('/kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/COVID19/COVID19(0).jpg')

img = img.convert('RGB')

img = img.resize((572, 572)) 
img_array = image.img_to_array(img) 

img_array = np.expand_dims(img_array, axis=0) 
img_array = img_array / 255.0

model = unet_model(input_shape=(572, 572, 3), num_classes=4)

predictions = model.predict(img_array)

predictions = np.squeeze(predictions, axis=0)
predictions = np.argmax(predictions, axis=-1)

predictions = Image.fromarray(np.uint8(predictions * 255))
predictions = predictions.resize((img.width, img.height))

predictions.save('predicted_image.jpg') 
predictions
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 12s 12s/step
# <PIL.Image.Image image mode=L size=572x572>

# %%
img = Image.open('/kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/NORMAL/IM-0001-0001.jpeg')

img = img.convert('RGB')

img = img.resize((572, 572)) 
img_array = image.img_to_array(img) 

img_array = np.expand_dims(img_array, axis=0) 
img_array = img_array / 255.0

model = unet_model(input_shape=(572, 572, 3), num_classes=2)

predictions = model.predict(img_array)

predictions = np.squeeze(predictions, axis=0)
predictions = np.argmax(predictions, axis=-1)

predictions = Image.fromarray(np.uint8(predictions * 255))
predictions = predictions.resize((img.width, img.height))

predictions.save('predicted_image.jpg') 
predictions
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# <PIL.Image.Image image mode=L size=572x572>

# %%
img = Image.open('/kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/PNEUMONIA/person1000_bacteria_2931.jpeg')

img = img.convert('RGB')

img = img.resize((572, 572)) 
img_array = image.img_to_array(img) 

img_array = np.expand_dims(img_array, axis=0) 
img_array = img_array / 255.0

model = unet_model(input_shape=(572, 572, 3), num_classes=2)

predictions = model.predict(img_array)

predictions = np.squeeze(predictions, axis=0)
predictions = np.argmax(predictions, axis=-1)

predictions = Image.fromarray(np.uint8(predictions * 255))
predictions = predictions.resize((img.width, img.height))

predictions.save('predicted_image.jpg') 
predictions
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 823ms/step
# <PIL.Image.Image image mode=L size=572x572>

# %%
img = Image.open('/kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/TURBERCULOSIS/Tuberculosis-1.png')

img = img.convert('RGB')

img = img.resize((572, 572)) 
img_array = image.img_to_array(img) 

img_array = np.expand_dims(img_array, axis=0) 
img_array = img_array / 255.0

model = unet_model(input_shape=(572, 572, 3), num_classes=2)

predictions = model.predict(img_array)

predictions = np.squeeze(predictions, axis=0)
predictions = np.argmax(predictions, axis=-1)

predictions = Image.fromarray(np.uint8(predictions * 255))
predictions = predictions.resize((img.width, img.height))

predictions.save('predicted_image.jpg') 
predictions
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 822ms/step
# <PIL.Image.Image image mode=L size=572x572>

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()

df['category_encoded'] = label_encoder.fit_transform(df['category'])

# %%
df
# Out:
#                                              image_path       category  \
# 0     /kaggle/input/chest-x-ray-dataset-4-categories...        COVID19
# 1     /kaggle/input/chest-x-ray-dataset-4-categories...        COVID19
# 2     /kaggle/input/chest-x-ray-dataset-4-categories...        COVID19
# 3     /kaggle/input/chest-x-ray-dataset-4-categories...        COVID19
# 4     /kaggle/input/chest-x-ray-dataset-4-categories...        COVID19
# ...                                                 ...            ...
# 7127  /kaggle/input/chest-x-ray-dataset-4-categories...  TURBERCULOSIS
# 7128  /kaggle/input/chest-x-ray-dataset-4-categories...  TURBERCULOSIS
# 7129  /kaggle/input/chest-x-ray-dataset-4-categories...  TURBERCULOSIS
# 7130  /kaggle/input/chest-x-ray-dataset-4-categories...  TURBERCULOSIS
# 7131  /kaggle/input/chest-x-ray-dataset-4-categories...  TURBERCULOSIS
#
#       category_encoded
# 0                    0
# 1                    0
# 2                    0
# 3                    0
# 4                    0
# ...                ...
# 7127                 3
# 7128                 3
# 7129                 3
# 7130                 3
# 7131                 3
#
# [7132 rows x 3 columns]

# %%
df = df[['image_path', 'category_encoded']]

# %%
from imblearn.over_sampling import RandomOverSampler

# %%
ros = RandomOverSampler(random_state=42)
X_resampled, y_resampled = ros.fit_resample(df[['image_path']], df['category_encoded'])

# %%
df_resampled = pd.DataFrame(X_resampled, columns=['image_path'])
df_resampled['category_encoded'] = y_resampled

# %%
print("\nClass distribution after oversampling:")
print(df_resampled['category_encoded'].value_counts())
# Out:
# Class distribution after oversampling:
# category_encoded
# 0    4273
# 1    4273
# 2    4273
# 3    4273
# Name: count, dtype: int64

# %%
df_resampled
# Out:
#                                               image_path  category_encoded
# 0      /kaggle/input/chest-x-ray-dataset-4-categories...                 0
# 1      /kaggle/input/chest-x-ray-dataset-4-categories...                 0
# 2      /kaggle/input/chest-x-ray-dataset-4-categories...                 0
# 3      /kaggle/input/chest-x-ray-dataset-4-categories...                 0
# 4      /kaggle/input/chest-x-ray-dataset-4-categories...                 0
# ...                                                  ...               ...
# 17087  /kaggle/input/chest-x-ray-dataset-4-categories...                 3
# 17088  /kaggle/input/chest-x-ray-dataset-4-categories...                 3
# 17089  /kaggle/input/chest-x-ray-dataset-4-categories...                 3
# 17090  /kaggle/input/chest-x-ray-dataset-4-categories...                 3
# 17091  /kaggle/input/chest-x-ray-dataset-4-categories...                 3
#
# [17092 rows x 2 columns]

# %%
df_resampled['category_encoded'] = df_resampled['category_encoded'].astype(str)

# %% [markdown]
# import os
# import tensorflow as tf
# from tensorflow.keras.preprocessing import image
# import numpy as np
#
# # Define the U-Net model (assuming encoder_block and decoder_block are defined)
# def unet_model(input_shape=(256, 256, 3), num_classes=2):
#     inputs = tf.keras.layers.Input(input_shape)
#
#     s1 = encoder_block(inputs, 64)
#     s2 = encoder_block(s1, 128)
#     s3 = encoder_block(s2, 256)
#     s4 = encoder_block(s3, 512)
#
#     b1 = tf.keras.layers.Conv2D(1024, 3, padding='valid')(s4)
#     b1 = tf.keras.layers.Activation('relu')(b1)
#     b1 = tf.keras.layers.Conv2D(1024, 3, padding='valid')(b1)
#     b1 = tf.keras.layers.Activation('relu')(b1)
#
#     s5 = decoder_block(b1, s4, 512)
#     s6 = decoder_block(s5, s3, 256)
#     s7 = decoder_block(s6, s2, 128)
#     s8 = decoder_block(s7, s1, 64)
#
#     outputs = tf.keras.layers.Conv2D(num_classes, 1, padding='valid', activation='sigmoid')(s8)
#
#     model = tf.keras.models.Model(inputs=inputs, outputs=outputs, name='U-Net')
#     return model
#
# # Function to create folders for each class
# def create_folders():
#     class_names = ['COVID19', 'NORMAL', 'PNEUMONIA', 'TUBERCULOSIS']
#     for class_name in class_names:
#         class_dir = os.path.join('/kaggle/working/', class_name)
#         if not os.path.exists(class_dir):
#             os.makedirs(class_dir)
#
# # Function to generate segmentation masks
# def generate_segmentation_masks(df, model, img_size=(256, 256)):
#     # Define the class names based on your categories
#     class_names = ['COVID19', 'NORMAL', 'PNEUMONIA', 'TUBERCULOSIS']
#
#     # Ensure category_encoded is of integer type
#     df['category_encoded'] = pd.to_numeric(df['category_encoded'], errors='coerce')
#
#     for idx, row in df.iterrows():
#         image_path = row['image_path']
#         class_label = row['category_encoded']  # This should now be an integer
#
#         # Ensure the class label is within the correct range
#         if class_label < 0 or class_label >= len(class_names):
#             print(f"Warning: Invalid class label {class_label} for image {image_path}. Skipping.")
#             continue
#
#         # Define the class name based on the label (integer value)
#         class_name = class_names[class_label]  # Map class_label to class name
#
#         # Load and preprocess the image
#         img = tf.keras.preprocessing.image.load_img(image_path, target_size=img_size)
#         img_array = tf.keras.preprocessing.image.img_to_array(img) / 255.0
#         img_array = tf.expand_dims(img_array, axis=0)  # Add batch dimension
#
#         # Predict segmentation mask using the trained model
#         pred_mask = model.predict(img_array)
#         pred_mask = tf.squeeze(pred_mask, axis=0)  # Remove batch dimension
#
#         # If the model has 2 channels (e.g., for binary classification), select one channel or threshold
#         if pred_mask.shape[-1] == 2:
#             # Choose the channel of interest (e.g., channel for the 'COVID19' class)
#             pred_mask = np.argmax(pred_mask, axis=-1)  # Convert to single-channel mask (class prediction)
#
#         # If it's a binary mask, ensure it's binary (0 or 1)
#         pred_mask = (pred_mask > 0.5).astype(np.uint8)
#
#         # Add the channel dimension to make it (height, width, 1)
#         pred_mask = np.expand_dims(pred_mask, axis=-1)
#
#         # Create the directory for the class if it doesn't exist
#         output_dir = f'/kaggle/working/{class_name}'
#         os.makedirs(output_dir, exist_ok=True)
#
#         # Save the predicted mask as an image
#         mask_image_path = os.path.join(output_dir, f'{os.path.basename(image_path)}_mask.png')
#         tf.keras.preprocessing.image.save_img(mask_image_path, pred_mask)
#
#         print(f"Saved mask for {image_path} to {mask_image_path}")
#
# # Now, you can use the model and df_resampled to generate masks
# # Example usage:
# # Assuming df_resampled is your dataframe
# model = unet_model(input_shape=(256, 256, 3), num_classes=2)  # Adjust num_classes for your use case
# generate_segmentation_masks(df_resampled, model)

# %%
import pandas as pd
import numpy as np
import os
import tensorflow as tf
from tensorflow.keras.preprocessing import image

def unet_model(input_shape=(256, 256, 3), num_classes=2):
    inputs = tf.keras.layers.Input(input_shape) 
    
    s1 = encoder_block(inputs, 64) 
    s2 = encoder_block(s1, 128) 
    s3 = encoder_block(s2, 256) 
    s4 = encoder_block(s3, 512) 
    
    b1 = tf.keras.layers.Conv2D(1024, 3, padding='valid')(s4) 
    b1 = tf.keras.layers.Activation('relu')(b1) 
    b1 = tf.keras.layers.Conv2D(1024, 3, padding='valid')(b1) 
    b1 = tf.keras.layers.Activation('relu')(b1) 
    
    s5 = decoder_block(b1, s4, 512) 
    s6 = decoder_block(s5, s3, 256) 
    s7 = decoder_block(s6, s2, 128) 
    s8 = decoder_block(s7, s1, 64) 
    
    outputs = tf.keras.layers.Conv2D(num_classes, 1, padding='valid', activation='sigmoid')(s8) 
    
    model = tf.keras.models.Model(inputs=inputs, outputs=outputs, name='U-Net') 
    return model

def create_folders():
    class_names = ['COVID19', 'NORMAL', 'PNEUMONIA', 'TUBERCULOSIS']
    for class_name in class_names:
        class_dir = os.path.join('/kaggle/working/', class_name)
        if not os.path.exists(class_dir):
            os.makedirs(class_dir)

def generate_segmentation_masks(df, model, img_size=(256, 256), num_images_per_class=100):
  
    class_names = ['COVID19', 'NORMAL', 'PNEUMONIA', 'TUBERCULOSIS']
    
    df['category_encoded'] = pd.to_numeric(df['category_encoded'], errors='coerce')
    
    for class_label in range(len(class_names)):
        class_df = df[df['category_encoded'] == class_label].sample(n=num_images_per_class, random_state=42)
        
        for idx, row in class_df.iterrows():
            image_path = row['image_path']
            class_label = row['category_encoded']  
          
            class_name = class_names[class_label]  
            
            img = tf.keras.preprocessing.image.load_img(image_path, target_size=img_size)
            img_array = tf.keras.preprocessing.image.img_to_array(img) / 255.0
            img_array = tf.expand_dims(img_array, axis=0)  
            
            pred_mask = model.predict(img_array)
            pred_mask = tf.squeeze(pred_mask, axis=0) 
            
            if pred_mask.shape[-1] == 2:
                
                pred_mask = np.argmax(pred_mask, axis=-1)  
            
            pred_mask = (pred_mask > 0.5).astype(np.uint8)
            
            pred_mask = np.expand_dims(pred_mask, axis=-1)
            
            output_dir = f'/kaggle/working/{class_name}'
            os.makedirs(output_dir, exist_ok=True)
            
            mask_image_path = os.path.join(output_dir, f'{os.path.basename(image_path)}_mask.png')
            tf.keras.preprocessing.image.save_img(mask_image_path, pred_mask)
            
            print(f"Saved mask for {image_path} to {mask_image_path}")


model = unet_model(input_shape=(256, 256, 3), num_classes=2) 
generate_segmentation_masks(df_resampled, model)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/COVID19/COVID19(240).jpg to /kaggle/working/COVID19/COVID19(240).jpg_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/COVID19/COVID19(170).jpg to /kaggle/working/COVID19/COVID19(170).jpg_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/COVID19/COVID19(395).jpg to /kaggle/working/COVID19/COVID19(395).jpg_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/COVID19/COVID19(4).jpg to /kaggle/working/COVID19/COVID19(4).jpg_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/COVID19/COVID19(200).jpg to /kaggle/working/COVID19/COVID19(200).jpg_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/COVID19/COVID19(379).jpg to /kaggle/working/COVID19/COVID19(379).jpg_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/COVID19/COVID19(354).jpg to /kaggle/working/COVID19/COVID19(354).jpg_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/COVID19/COVID19(107).jpg to /kaggle/working/COVID19/COVID19(107).jpg_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/COVID19/COVID19(108).jpg to /kaggle/working/COVID19/COVID19(108).jpg_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/COVID19/COVID19(63).jpg to /kaggle/working/COVID19/COVID19(63).jpg_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/COVID19/COVID19(390).jpg to /kaggle/working/COVID19/COVID19(390).jpg_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/COVID19/COVID19(540).jpg to /kaggle/working/COVID19/COVID19(540).jpg_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/COVID19/COVID19(81).jpg to /kaggle/working/COVID19/COVID19(81).jpg_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/COVID19/COVID19(305).jpg to /kaggle/working/COVID19/COVID19(305).jpg_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/COVID19/COVID19(215).jpg to /kaggle/working/COVID19/COVID19(215).jpg_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/COVID19/COVID19(422).jpg to /kaggle/working/COVID19/COVID19(422).jpg_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/COVID19/COVID19(13).jpg to /kaggle/working/COVID19/COVID19(13).jpg_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/COVID19/COVID19(398).jpg to /kaggle/working/COVID19/COVID19(398).jpg_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/COVID19/COVID19(136).jpg to /kaggle/working/COVID19/COVID19(136).jpg_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/COVID19/COVID19(528).jpg to /kaggle/working/COVID19/COVID19(528).jpg_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/COVID19/COVID19(35).jpg to /kaggle/working/COVID19/COVID19(35).jpg_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/COVID19/COVID19(325).jpg to /kaggle/working/COVID19/COVID19(325).jpg_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/COVID19/COVID19(565).jpg to /kaggle/working/COVID19/COVID19(565).jpg_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/COVID19/COVID19(447).jpg to /kaggle/working/COVID19/COVID19(447).jpg_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/COVID19/COVID19(514).jpg to /kaggle/working/COVID19/COVID19(514).jpg_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/COVID19/COVID19(431).jpg to /kaggle/working/COVID19/COVID19(431).jpg_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/COVID19/COVID19(245).jpg to /kaggle/working/COVID19/COVID19(245).jpg_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/COVID19/COVID19(439).jpg to /kaggle/working/COVID19/COVID19(439).jpg_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/COVID19/COVID19(495).jpg to /kaggle/working/COVID19/COVID19(495).jpg_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/COVID19/COVID19(360).jpg to /kaggle/working/COVID19/COVID19(360).jpg_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/COVID19/COVID19(19).jpg to /kaggle/working/COVID19/COVID19(19).jpg_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/COVID19/COVID19(239).jpg to /kaggle/working/COVID19/COVID19(239).jpg_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/COVID19/COVID19(562).jpg to /kaggle/working/COVID19/COVID19(562).jpg_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/COVID19/COVID19(360).jpg to /kaggle/working/COVID19/COVID19(360).jpg_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/COVID19/COVID19(82).jpg to /kaggle/working/COVID19/COVID19(82).jpg_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/COVID19/COVID19(547).jpg to /kaggle/working/COVID19/COVID19(547).jpg_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/COVID19/COVID19(378).jpg to /kaggle/working/COVID19/COVID19(378).jpg_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/COVID19/COVID19(8).jpg to /kaggle/working/COVID19/COVID19(8).jpg_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/COVID19/COVID19(566).jpg to /kaggle/working/COVID19/COVID19(566).jpg_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/COVID19/COVID19(453).jpg to /kaggle/working/COVID19/COVID19(453).jpg_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/COVID19/COVID19
0001.jpeg_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/NORMAL/IM-0033-0001-0001.jpeg to /kaggle/working/NORMAL/IM-0033-0001-0001.jpeg_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/NORMAL/NORMAL2-IM-1008-0001.jpeg to /kaggle/working/NORMAL/NORMAL2-IM-1008-0001.jpeg_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/NORMAL/NORMAL2-IM-0587-0001.jpeg to /kaggle/working/NORMAL/NORMAL2-IM-0587-0001.jpeg_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/NORMAL/IM-0304-0001.jpeg to /kaggle/working/NORMAL/IM-0304-0001.jpeg_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/NORMAL/IM-0625-0001.jpeg to /kaggle/working/NORMAL/IM-0625-0001.jpeg_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/NORMAL/IM-0220-0001.jpeg to /kaggle/working/NORMAL/IM-0220-0001.jpeg_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/NORMAL/NORMAL2-IM-0364-0001.jpeg to /kaggle/working/NORMAL/NORMAL2-IM-0364-0001.jpeg_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/NORMAL/IM-0011-0001-0001.jpeg to /kaggle/working/NORMAL/IM-0011-0001-0001.jpeg_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/NORMAL/NORMAL2-IM-1376-0001.jpeg to /kaggle/working/NORMAL/NORMAL2-IM-1376-0001.jpeg_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/NORMAL/NORMAL2-IM-1400-0001.jpeg to /kaggle/working/NORMAL/NORMAL2-IM-1400-0001.jpeg_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/NORMAL/IM-0182-0001.jpeg to /kaggle/working/NORMAL/IM-0182-0001.jpeg_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/NORMAL/NORMAL2-IM-1267-0001.jpeg to /kaggle/working/NORMAL/NORMAL2-IM-1267-0001.jpeg_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/NORMAL/NORMAL2-IM-1274-0001.jpeg to /kaggle/working/NORMAL/NORMAL2-IM-1274-0001.jpeg_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/NORMAL/NORMAL2-IM-0912-0001.jpeg to /kaggle/working/NORMAL/NORMAL2-IM-0912-0001.jpeg_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/NORMAL/NORMAL2-IM-0030-0001.jpeg to /kaggle/working/NORMAL/NORMAL2-IM-0030-0001.jpeg_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/NORMAL/NORMAL2-IM-0589-0001.jpeg to /kaggle/working/NORMAL/NORMAL2-IM-0589-0001.jpeg_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/NORMAL/IM-0419-0001.jpeg to /kaggle/working/NORMAL/IM-0419-0001.jpeg_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/NORMAL/NORMAL2-IM-0340-0001.jpeg to /kaggle/working/NORMAL/NORMAL2-IM-0340-0001.jpeg_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/NORMAL/NORMAL2-IM-0513-0001.jpeg to /kaggle/working/NORMAL/NORMAL2-IM-0513-0001.jpeg_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/NORMAL/NORMAL2-IM-1240-0001.jpeg to /kaggle/working/NORMAL/NORMAL2-IM-1240-0001.jpeg_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/NORMAL/IM-0109-0001.jpeg to /kaggle/working/NORMAL/IM-0109-0001.jpeg_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/NORMAL/NORMAL2-IM-0858-0001.jpeg to /kaggle/working/NORMAL/NORMAL2-IM-0858-0001.jpeg_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/NORMAL/NORMAL2-IM-1336-0001.jpeg to /kaggle/working/NORMAL/NORMAL2-IM-1336-0001.jpeg_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/NORMAL/IM-0377-0001.jpeg to /kaggle/working/NORMAL/IM-0377-0001.jpeg_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/NORMAL/IM-0164-0001.jpeg to /kaggle/working/NORMAL/IM-0164-0001.jpeg_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/NORMAL/NORMAL2-IM-0651-0004.jpeg to /kaggle/working/NORMAL/NORMAL2-IM-0651-0004.jpeg_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/NORMAL/IM-0643-0001.jpeg to /kaggle/working/NORMAL/IM-0643-0001.jpeg_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/NORMAL/NORMAL2-IM-0834-0001.jpeg to /kaggle/working/NORMAL/NORMAL2-IM-0834-0001.jpeg_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/NORMAL/NORMAL2-IM-0641-0001.jpeg to /kaggle/working/NORMAL/NORMAL2-IM-0641-0001.jpeg_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/NORMAL/NORMAL2-IM-0392-0001.jpeg to /kaggle/working/NORMAL/NORMAL2-IM-0392-0001.jpeg_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/NORMAL/IM-0238-0001.jpeg to /kaggle/working/NORMAL/IM-0238-0001.jpeg_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/NORMAL/IM-0119-0001.jpeg to /kaggle/working/NORMAL/IM-0119-0001.jpeg_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/PNEUMONIA/person374_bacteria_1712.jpeg to /kaggle/working/PNEUMONIA/person374_bacteria_1712.jpeg_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/PNEUMONIA/person811_virus_1447.jpeg to /kaggle/working/PNEUMONIA/person811_virus_1447.jpeg_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/PNEUMONIA/person593_bacteria_2435.jpeg to /kaggle/working/PNEUMONIA/person593_bacteria_2435.jpeg_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/PNEUMONIA/person1604_virus_2782.jpeg to /kaggle/working/PNEUMONIA/person1604_virus_2782.jpeg_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/PNEUMONIA/person744_bacteria_2647.jpeg to /kaggle/working/PNEUMONIA/person744_bacteria_2647.jpeg_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/PNEUMONIA/person1405_bacteria_3573.jpeg to /kaggle/working/PNEUMONIA/person1405_bacteria_3573.jpeg_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/PNEUMONIA/person1918_bacteria_4825.jpeg to /kaggle/working/PNEUMONIA/person1918_bacteria_4825.jpeg_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/PNEUMONIA/person525_bacteria_2217.jpeg to /kaggle/working/PNEUMONIA/person525_bacteria_2217.jpeg_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/PNEUMONIA/person347_bacteria_1597.jpeg to /kaggle/working/PNEUMONIA/person347_bacteria_1597.jpeg_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/PNEUMONIA/person33_bacteria_175.jpeg to /kaggle/working/PNEUMONIA/person33_bacteria_175.jpeg_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/PNEUMONIA/person337_bacteria_1563.jpeg to /kaggle/working/PNEUMONIA/person337_bacteria_1563.jpeg_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/PNEUMONIA/person548_bacteria_2297.jpeg to /kaggle/working/PNEUMONIA/person548_bacteria_2297.jpeg_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/PNEUMONIA/person87_bacteria_433.jpeg to /kaggle/working/PNEUMONIA/person87_bacteria_433.jpeg_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/PNEUMONIA/person382_bacteria_1741.jpeg to /kaggle/working/PNEUMONIA/person382_bacteria_1741.jpeg_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/PNEUMONIA/person944_bacteria_2869.jpeg to /kaggle/working/PNEUMONIA/person944_bacteria_2869.jpeg_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/PNEUMONIA/person504_bacteria_2132.jpeg to /kaggle/working/PNEUMONIA/person504_bacteria_2132.jpeg_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/PNEUMONIA/person326_bacteria_1504.jpeg to /kaggle/working/PNEUMONIA/person326_bacteria_1504.jpeg_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/PNEUMONIA/person466_bacteria_1987.jpeg to /kaggle/working/PNEUMONIA/person466_bacteria_1987.jpeg_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/PNEUMONIA/person383_bacteria_1752.jpeg to /kaggle/working/PNEUMONIA/person383_bacteria_1752.jpeg_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/PNEUMONIA/person940_virus_1609.jpeg to /kaggle/working/PNEUMONIA/person940_virus_1609.jpeg_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/PNEUMONIA/person1866_bacteria_4740.jpeg to /kaggle/working/PNEUMONIA/person1866_bacteria_4740.jpeg_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/PNEUMONIA/person309_virus_631.jpeg to /kaggle/working/PNEUMONIA/person309_virus_631.jpeg_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/PNEUMONIA/person1175_bacteria_3122.jpeg to /kaggle/working/PNEUMONIA/person1175_bacteria_3122.jpeg_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/PNEUMONIA/person683_bacteria_2578.jpeg to /kaggle/working/PNEUMONIA/person683_bacteria_2578.jpeg_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/PNEUMONIA/person1506_bacteria_3933.jpeg to /kaggle/working/PNEUMONIA/person1506_bacteria_3933.jpeg_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/PNEUMONIA/person913_bacteria_2838.jpeg to /kaggle/working/PNEUMONIA/person913_bacteria_2838.jpeg_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/PNEUMONIA/person1473_virus_2551.jpeg to /kaggle/working/PNEUMONIA/person1473_virus_2551.jpeg_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/PNEUMONIA/person278_bacteria_1313.jpeg to /kaggle/working/PNEUMONIA/person278_bacteria_1313.jpeg_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/PNEUMONIA/person445_bacteria_1929.jpeg to /kaggle/working/PNEUMONIA/person445_bacteria_1929.jpeg_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/PNEUMONIA/person460_bacteria_1958.jpeg to /kaggle/working/PNEUMONIA/person460_bacteria_1958.jpeg_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/PNEUMONIA/person1343_bacteria_3409.jpeg to /kaggle/working/PNEUMONIA/person1343_bacteria_3409.jpeg_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/PNEUMONIA/person91_bacteria_449.jpeg to /kaggle/working/PNEUMONIA/person91_bacteria_449.jpeg_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# ...
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/TURBERCULOSIS/Tuberculosis-218.png to /kaggle/working/TUBERCULOSIS/Tuberculosis-218.png_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/TURBERCULOSIS/Tuberculosis-67.png to /kaggle/working/TUBERCULOSIS/Tuberculosis-67.png_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/TURBERCULOSIS/Tuberculosis-236.png to /kaggle/working/TUBERCULOSIS/Tuberculosis-236.png_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/TURBERCULOSIS/Tuberculosis-496.png to /kaggle/working/TUBERCULOSIS/Tuberculosis-496.png_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/TURBERCULOSIS/Tuberculosis-323.png to /kaggle/working/TUBERCULOSIS/Tuberculosis-323.png_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/TURBERCULOSIS/Tuberculosis-116.png to /kaggle/working/TUBERCULOSIS/Tuberculosis-116.png_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/TURBERCULOSIS/Tuberculosis-436.png to /kaggle/working/TUBERCULOSIS/Tuberculosis-436.png_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/TURBERCULOSIS/Tuberculosis-606.png to /kaggle/working/TUBERCULOSIS/Tuberculosis-606.png_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/TURBERCULOSIS/Tuberculosis-183.png to /kaggle/working/TUBERCULOSIS/Tuberculosis-183.png_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/TURBERCULOSIS/Tuberculosis-624.png to /kaggle/working/TUBERCULOSIS/Tuberculosis-624.png_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/TURBERCULOSIS/Tuberculosis-46.png to /kaggle/working/TUBERCULOSIS/Tuberculosis-46.png_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/TURBERCULOSIS/Tuberculosis-625.png to /kaggle/working/TUBERCULOSIS/Tuberculosis-625.png_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/TURBERCULOSIS/Tuberculosis-585.png to /kaggle/working/TUBERCULOSIS/Tuberculosis-585.png_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/TURBERCULOSIS/Tuberculosis-74.png to /kaggle/working/TUBERCULOSIS/Tuberculosis-74.png_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/TURBERCULOSIS/Tuberculosis-448.png to /kaggle/working/TUBERCULOSIS/Tuberculosis-448.png_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/TURBERCULOSIS/Tuberculosis-258.png to /kaggle/working/TUBERCULOSIS/Tuberculosis-258.png_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/TURBERCULOSIS/Tuberculosis-501.png to /kaggle/working/TUBERCULOSIS/Tuberculosis-501.png_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/TURBERCULOSIS/Tuberculosis-593.png to /kaggle/working/TUBERCULOSIS/Tuberculosis-593.png_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/TURBERCULOSIS/Tuberculosis-325.png to /kaggle/working/TUBERCULOSIS/Tuberculosis-325.png_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/TURBERCULOSIS/Tuberculosis-85.png to /kaggle/working/TUBERCULOSIS/Tuberculosis-85.png_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/TURBERCULOSIS/Tuberculosis-262.png to /kaggle/working/TUBERCULOSIS/Tuberculosis-262.png_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/TURBERCULOSIS/Tuberculosis-134.png to /kaggle/working/TUBERCULOSIS/Tuberculosis-134.png_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/TURBERCULOSIS/Tuberculosis-593.png to /kaggle/working/TUBERCULOSIS/Tuberculosis-593.png_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/TURBERCULOSIS/Tuberculosis-162.png to /kaggle/working/TUBERCULOSIS/Tuberculosis-162.png_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/TURBERCULOSIS/Tuberculosis-45.png to /kaggle/working/TUBERCULOSIS/Tuberculosis-45.png_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/TURBERCULOSIS/Tuberculosis-353.png to /kaggle/working/TUBERCULOSIS/Tuberculosis-353.png_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/TURBERCULOSIS/Tuberculosis-8.png to /kaggle/working/TUBERCULOSIS/Tuberculosis-8.png_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/TURBERCULOSIS/Tuberculosis-30.png to /kaggle/working/TUBERCULOSIS/Tuberculosis-30.png_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/TURBERCULOSIS/Tuberculosis-295.png to /kaggle/working/TUBERCULOSIS/Tuberculosis-295.png_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/TURBERCULOSIS/Tuberculosis-433.png to /kaggle/working/TUBERCULOSIS/Tuberculosis-433.png_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/TURBERCULOSIS/Tuberculosis-384.png to /kaggle/working/TUBERCULOSIS/Tuberculosis-384.png_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/TURBERCULOSIS/Tuberculosis-78.png to /kaggle/working/TUBERCULOSIS/Tuberculosis-78.png_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/TURBERCULOSIS/Tuberculosis-600.png to /kaggle/working/TUBERCULOSIS/Tuberculosis-600.png_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/TURBERCULOSIS/Tuberculosis-480.png to /kaggle/working/TUBERCULOSIS/Tuberculosis-480.png_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/TURBERCULOSIS/Tuberculosis-68.png to /kaggle/working/TUBERCULOSIS/Tuberculosis-68.png_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/TURBERCULOSIS/Tuberculosis-645.png to /kaggle/working/TUBERCULOSIS/Tuberculosis-645.png_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/TURBERCULOSIS/Tuberculosis-598.png to /kaggle/working/TUBERCULOSIS/Tuberculosis-598.png_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/TURBERCULOSIS/Tuberculosis-415.png to /kaggle/working/TUBERCULOSIS/Tuberculosis-415.png_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/TURBERCULOSIS/Tuberculosis-15.png to /kaggle/working/TUBERCULOSIS/Tuberculosis-15.png_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/TURBERCULOSIS/Tuberculosis-311.png to /kaggle/working/TUBERCULOSIS/Tuberculosis-311.png_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/TURBERCULOSIS/Tuberculosis-255.png to /kaggle/working/TUBERCULOSIS/Tuberculosis-255.png_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/TURBERCULOSIS/Tuberculosis-547.png to /kaggle/working/TUBERCULOSIS/Tuberculosis-547.png_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/TURBERCULOSIS/Tuberculosis-500.png to /kaggle/working/TUBERCULOSIS/Tuberculosis-500.png_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/TURBERCULOSIS/Tuberculosis-311.png to /kaggle/working/TUBERCULOSIS/Tuberculosis-311.png_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/TURBERCULOSIS/Tuberculosis-143.png to /kaggle/working/TUBERCULOSIS/Tuberculosis-143.png_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/TURBERCULOSIS/Tuberculosis-539.png to /kaggle/working/TUBERCULOSIS/Tuberculosis-539.png_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/TURBERCULOSIS/Tuberculosis-257.png to /kaggle/working/TUBERCULOSIS/Tuberculosis-257.png_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/TURBERCULOSIS/Tuberculosis-570.png to /kaggle/working/TUBERCULOSIS/Tuberculosis-570.png_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/TURBERCULOSIS/Tuberculosis-130.png to /kaggle/working/TUBERCULOSIS/Tuberculosis-130.png_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/TURBERCULOSIS/Tuberculosis-555.png to /kaggle/working/TUBERCULOSIS/Tuberculosis-555.png_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/TURBERCULOSIS/Tuberculosis-513.png to /kaggle/working/TUBERCULOSIS/Tuberculosis-513.png_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/TURBERCULOSIS/Tuberculosis-513.png to /kaggle/working/TUBERCULOSIS/Tuberculosis-513.png_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/TURBERCULOSIS/Tuberculosis-65.png to /kaggle/working/TUBERCULOSIS/Tuberculosis-65.png_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/TURBERCULOSIS/Tuberculosis-687.png to /kaggle/working/TUBERCULOSIS/Tuberculosis-687.png_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/TURBERCULOSIS/Tuberculosis-408.png to /kaggle/working/TUBERCULOSIS/Tuberculosis-408.png_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/TURBERCULOSIS/Tuberculosis-365.png to /kaggle/working/TUBERCULOSIS/Tuberculosis-365.png_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/TURBERCULOSIS/Tuberculosis-440.png to /kaggle/working/TUBERCULOSIS/Tuberculosis-440.png_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/TURBERCULOSIS/Tuberculosis-190.png to /kaggle/working/TUBERCULOSIS/Tuberculosis-190.png_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/TURBERCULOSIS/Tuberculosis-345.png to /kaggle/working/TUBERCULOSIS/Tuberculosis-345.png_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/TURBERCULOSIS/Tuberculosis-533.png to /kaggle/working/TUBERCULOSIS/Tuberculosis-533.png_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/TURBERCULOSIS/Tuberculosis-220.png to /kaggle/working/TUBERCULOSIS/Tuberculosis-220.png_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/TURBERCULOSIS/Tuberculosis-413.png to /kaggle/working/TUBERCULOSIS/Tuberculosis-413.png_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/TURBERCULOSIS/Tuberculosis-447.png to /kaggle/working/TUBERCULOSIS/Tuberculosis-447.png_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/TURBERCULOSIS/Tuberculosis-285.png to /kaggle/working/TUBERCULOSIS/Tuberculosis-285.png_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/TURBERCULOSIS/Tuberculosis-374.png to /kaggle/working/TUBERCULOSIS/Tuberculosis-374.png_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/TURBERCULOSIS/Tuberculosis-228.png to /kaggle/working/TUBERCULOSIS/Tuberculosis-228.png_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/TURBERCULOSIS/Tuberculosis-226.png to /kaggle/working/TUBERCULOSIS/Tuberculosis-226.png_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/TURBERCULOSIS/Tuberculosis-223.png to /kaggle/working/TUBERCULOSIS/Tuberculosis-223.png_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/TURBERCULOSIS/Tuberculosis-156.png to /kaggle/working/TUBERCULOSIS/Tuberculosis-156.png_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/TURBERCULOSIS/Tuberculosis-510.png to /kaggle/working/TUBERCULOSIS/Tuberculosis-510.png_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/TURBERCULOSIS/Tuberculosis-163.png to /kaggle/working/TUBERCULOSIS/Tuberculosis-163.png_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/TURBERCULOSIS/Tuberculosis-517.png to /kaggle/working/TUBERCULOSIS/Tuberculosis-517.png_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/TURBERCULOSIS/Tuberculosis-428.png to /kaggle/working/TUBERCULOSIS/Tuberculosis-428.png_mask.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Saved mask for /kaggle/input/chest-x-ray-dataset-4-categories/Chest X_Ray Dataset/TURBERCULOSIS/Tuberculosis-97.png to /kaggle/working/TUBERCULOSIS/Tuberculosis-97.png_mask.png

# %%
df_resampled
# Out:
#                                               image_path  category_encoded
# 0      /kaggle/input/chest-x-ray-dataset-4-categories...                 0
# 1      /kaggle/input/chest-x-ray-dataset-4-categories...                 0
# 2      /kaggle/input/chest-x-ray-dataset-4-categories...                 0
# 3      /kaggle/input/chest-x-ray-dataset-4-categories...                 0
# 4      /kaggle/input/chest-x-ray-dataset-4-categories...                 0
# ...                                                  ...               ...
# 17087  /kaggle/input/chest-x-ray-dataset-4-categories...                 3
# 17088  /kaggle/input/chest-x-ray-dataset-4-categories...                 3
# 17089  /kaggle/input/chest-x-ray-dataset-4-categories...                 3
# 17090  /kaggle/input/chest-x-ray-dataset-4-categories...                 3
# 17091  /kaggle/input/chest-x-ray-dataset-4-categories...                 3
#
# [17092 rows x 2 columns]

# %%
import cv2
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Activation, Dropout, BatchNormalization
from tensorflow.keras import regularizers

import warnings
warnings.filterwarnings("ignore")

print ('check')
# Out:
# check

# %%
df_resampled['category_encoded'] = df_resampled['category_encoded'].astype(str)

# %%
train_df_new, temp_df_new = train_test_split(
    df_resampled,
    train_size=0.8,  
    shuffle=True,
    random_state=42,
    stratify=df_resampled['category_encoded']  
)

valid_df_new, test_df_new = train_test_split(
    temp_df_new,
    test_size=0.5,  
    shuffle=True,
    random_state=42,
    stratify=temp_df_new['category_encoded'] 
)

# %%
batch_size = 16
img_size = (256, 256)
channels = 3  
img_shape = (img_size[0], img_size[1], channels)

tr_gen = ImageDataGenerator(rescale=1./255)  
ts_gen = ImageDataGenerator(rescale=1./255)

train_gen_new = tr_gen.flow_from_dataframe(
    train_df_new,
    x_col='image_path',  
    y_col='category_encoded',     
    target_size=img_size,
    class_mode='sparse',  
    color_mode='rgb', 
    shuffle=True,
    batch_size=batch_size
)

valid_gen_new = ts_gen.flow_from_dataframe(
    valid_df_new,
    x_col='image_path',  
    y_col='category_encoded',     
    target_size=img_size,
    class_mode='sparse',  
    color_mode='rgb', 
    shuffle=True,
    batch_size=batch_size
)

test_gen_new = ts_gen.flow_from_dataframe(
    test_df_new,
    x_col='image_path', 
    y_col='category_encoded',    
    target_size=img_size,
    class_mode='sparse',  
    color_mode='rgb', 
    shuffle=False,  
    batch_size=batch_size
)
# Out:
# Found 13673 validated image filenames belonging to 4 classes.
# Found 1709 validated image filenames belonging to 4 classes.
# Found 1710 validated image filenames belonging to 4 classes.

# %%
physical_devices = tf.config.list_physical_devices('GPU')
if physical_devices:
    print("Using GPU")
else:
    print("Using CPU")
# Out:
# Using GPU

# %%
from tensorflow.keras import layers, models
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# %%
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# %%
def unet_classification_model(input_size=(256, 256, 3), num_classes=4):
    inputs = layers.Input(input_size)

    conv1 = layers.Conv2D(64, (3, 3), activation='relu', padding='same')(inputs)
    conv1 = layers.Conv2D(64, (3, 3), activation='relu', padding='same')(conv1)
    pool1 = layers.MaxPooling2D((2, 2))(conv1)

    conv2 = layers.Conv2D(128, (3, 3), activation='relu', padding='same')(pool1)
    conv2 = layers.Conv2D(128, (3, 3), activation='relu', padding='same')(conv2)
    pool2 = layers.MaxPooling2D((2, 2))(conv2)

    conv3 = layers.Conv2D(256, (3, 3), activation='relu', padding='same')(pool2)
    conv3 = layers.Conv2D(256, (3, 3), activation='relu', padding='same')(conv3)
    pool3 = layers.MaxPooling2D((2, 2))(conv3)

    bottleneck = layers.Conv2D(512, (3, 3), activation='relu', padding='same')(pool3)
    bottleneck = layers.Conv2D(512, (3, 3), activation='relu', padding='same')(bottleneck)

    upconv3 = layers.Conv2DTranspose(256, (2, 2), strides=(2, 2), padding='same')(bottleneck)
    concat3 = layers.concatenate([upconv3, conv3])
    conv4 = layers.Conv2D(256, (3, 3), activation='relu', padding='same')(concat3)
    conv4 = layers.Conv2D(256, (3, 3), activation='relu', padding='same')(conv4)

    upconv2 = layers.Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(conv4)
    concat2 = layers.concatenate([upconv2, conv2])
    conv5 = layers.Conv2D(128, (3, 3), activation='relu', padding='same')(concat2)
    conv5 = layers.Conv2D(128, (3, 3), activation='relu', padding='same')(conv5)

    upconv1 = layers.Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(conv5)
    concat1 = layers.concatenate([upconv1, conv1])
    conv6 = layers.Conv2D(64, (3, 3), activation='relu', padding='same')(concat1)
    conv6 = layers.Conv2D(64, (3, 3), activation='relu', padding='same')(conv6)

    gap = layers.GlobalAveragePooling2D()(conv6)  

    output = layers.Dense(num_classes, activation='softmax')(gap)

    model = tf.keras.Model(inputs=inputs, outputs=output)
    return model

model = unet_classification_model(input_size=(256, 256, 3), num_classes=4)
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_6             │ (None, 256, 256, 3)    │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_114 (Conv2D)       │ (None, 256, 256, 64)   │          1,792 │ input_layer_6[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_115 (Conv2D)       │ (None, 256, 256, 64)   │         36,928 │ conv2d_114[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_24          │ (None, 128, 128, 64)   │              0 │ conv2d_115[0][0]       │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_116 (Conv2D)       │ (None, 128, 128, 128)  │         73,856 │ max_pooling2d_24[0][0] │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_117 (Conv2D)       │ (None, 128, 128, 128)  │        147,584 │ conv2d_116[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_25          │ (None, 64, 64, 128)    │              0 │ conv2d_117[0][0]       │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_118 (Conv2D)       │ (None, 64, 64, 256)    │        295,168 │ max_pooling2d_25[0][0] │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_119 (Conv2D)       │ (None, 64, 64, 256)    │        590,080 │ conv2d_118[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_26          │ (None, 32, 32, 256)    │              0 │ conv2d_119[0][0]       │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_120 (Conv2D)       │ (None, 32, 32, 512)    │      1,180,160 │ max_pooling2d_26[0][0] │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_121 (Conv2D)       │ (None, 32, 32, 512)    │      2,359,808 │ conv2d_120[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose_24       │ (None, 64, 64, 256)    │        524,544 │ conv2d_121[0][0]       │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_24            │ (None, 64, 64, 512)    │              0 │ conv2d_transpose_24[0… │
# │ (Concatenate)             │                        │                │ conv2d_119[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_122 (Conv2D)       │ (None, 64, 64, 256)    │      1,179,904 │ concatenate_24[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_123 (Conv2D)       │ (None, 64, 64, 256)    │        590,080 │ conv2d_122[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose_25       │ (None, 128, 128, 128)  │        131,200 │ conv2d_123[0][0]       │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_25            │ (None, 128, 128, 256)  │              0 │ conv2d_transpose_25[0… │
# │ (Concatenate)             │                        │                │ conv2d_117[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_124 (Conv2D)       │ (None, 128, 128, 128)  │        295,040 │ concatenate_25[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_125 (Conv2D)       │ (None, 128, 128, 128)  │        147,584 │ conv2d_124[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose_26       │ (None, 256, 256, 64)   │         32,832 │ conv2d_125[0][0]       │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_26            │ (None, 256, 256, 128)  │              0 │ conv2d_transpose_26[0… │
# │ (Concatenate)             │                        │                │ conv2d_115[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_126 (Conv2D)       │ (None, 256, 256, 64)   │         73,792 │ concatenate_26[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_127 (Conv2D)       │ (None, 256, 256, 64)   │         36,928 │ conv2d_126[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_average_pooling2d  │ (None, 64)             │              0 │ conv2d_127[0][0]       │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense (Dense)             │ (None, 4)              │            260 │ global_average_poolin… │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 7,697,540 (29.36 MB)
#  Trainable params: 7,697,540 (29.36 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
history = model.fit(
    train_gen_new,  
    epochs=5,
    batch_size=16,
    validation_data=valid_gen_new,  
    steps_per_epoch=train_gen_new.samples // train_gen_new.batch_size,
    validation_steps=valid_gen_new.samples // valid_gen_new.batch_size,
    verbose=1
)
# Out:
# Epoch 1/5
# 854/854 ━━━━━━━━━━━━━━━━━━━━ 692s 739ms/step - accuracy: 0.4033 - loss: 1.2847 - val_accuracy: 0.4847 - val_loss: 1.2386
# Epoch 2/5
# 854/854 ━━━━━━━━━━━━━━━━━━━━ 22s 25ms/step - accuracy: 0.5625 - loss: 1.1575 - val_accuracy: 0.4615 - val_loss: 1.2466
# Epoch 3/5
# 854/854 ━━━━━━━━━━━━━━━━━━━━ 559s 652ms/step - accuracy: 0.5382 - loss: 1.1013 - val_accuracy: 0.7836 - val_loss: 0.5935
# Epoch 4/5
# 854/854 ━━━━━━━━━━━━━━━━━━━━ 1s 214us/step - accuracy: 0.6875 - loss: 0.6110 - val_accuracy: 0.8462 - val_loss: 0.4627
# Epoch 5/5
# 854/854 ━━━━━━━━━━━━━━━━━━━━ 546s 637ms/step - accuracy: 0.7832 - loss: 0.5536 - val_accuracy: 0.8620 - val_loss: 0.3569

# %%
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Model Accuracy')
plt.legend()
plt.show()

plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Model Loss')
plt.legend()
plt.show()

# %%
y_pred_probs = model.predict(test_gen_new)
y_pred = np.argmax(y_pred_probs, axis=1)
# Out:
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 51s 470ms/step

# %%
y_true = test_gen_new.classes

# %%
cm = confusion_matrix(y_true, y_pred)

plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=test_gen_new.class_indices.keys(), yticklabels=test_gen_new.class_indices.keys())
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()

# %%
from sklearn.metrics import classification_report

report = classification_report(y_true, y_pred, target_names=test_gen_new.class_indices.keys())
print("Classification Report:\n", report)
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.92      0.84      0.88       427
#            1       0.84      0.78      0.81       427
#            2       0.78      0.89      0.83       428
#            3       0.91      0.94      0.92       428
#
#     accuracy                           0.86      1710
#    macro avg       0.86      0.86      0.86      1710
# weighted avg       0.86      0.86      0.86      1710

# %%
def attention_gate(x, g, inter_channels):
    """Attention Gate Implementation."""
    theta_x = layers.Conv2D(inter_channels, (1, 1), strides=(1, 1), padding='same')(x)
    phi_g = layers.Conv2D(inter_channels, (1, 1), strides=(1, 1), padding='same')(g)
    add_xg = layers.Add()([theta_x, phi_g])
    relu_xg = layers.Activation('relu')(add_xg)
    psi = layers.Conv2D(1, (1, 1), strides=(1, 1), padding='same')(relu_xg)
    sigmoid_xg = layers.Activation('sigmoid')(psi)
    attention = layers.Multiply()([x, sigmoid_xg])
    return attention

def unet_with_attention(input_size=(256, 256, 3), num_classes=4):
    inputs = layers.Input(input_size)

    conv1 = layers.Conv2D(64, (3, 3), activation='relu', padding='same')(inputs)
    conv1 = layers.Conv2D(64, (3, 3), activation='relu', padding='same')(conv1)
    pool1 = layers.MaxPooling2D((2, 2))(conv1)

    conv2 = layers.Conv2D(128, (3, 3), activation='relu', padding='same')(pool1)
    conv2 = layers.Conv2D(128, (3, 3), activation='relu', padding='same')(conv2)
    pool2 = layers.MaxPooling2D((2, 2))(conv2)

    conv3 = layers.Conv2D(256, (3, 3), activation='relu', padding='same')(pool2)
    conv3 = layers.Conv2D(256, (3, 3), activation='relu', padding='same')(conv3)
    pool3 = layers.MaxPooling2D((2, 2))(conv3)

    bottleneck = layers.Conv2D(512, (3, 3), activation='relu', padding='same')(pool3)
    bottleneck = layers.Conv2D(512, (3, 3), activation='relu', padding='same')(bottleneck)

    upconv3 = layers.Conv2DTranspose(256, (2, 2), strides=(2, 2), padding='same')(bottleneck)
    attn3 = attention_gate(conv3, upconv3, inter_channels=128)
    concat3 = layers.concatenate([upconv3, attn3])
    conv4 = layers.Conv2D(256, (3, 3), activation='relu', padding='same')(concat3)
    conv4 = layers.Conv2D(256, (3, 3), activation='relu', padding='same')(conv4)

    upconv2 = layers.Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(conv4)
    attn2 = attention_gate(conv2, upconv2, inter_channels=64)
    concat2 = layers.concatenate([upconv2, attn2])
    conv5 = layers.Conv2D(128, (3, 3), activation='relu', padding='same')(concat2)
    conv5 = layers.Conv2D(128, (3, 3), activation='relu', padding='same')(conv5)

    upconv1 = layers.Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(conv5)
    attn1 = attention_gate(conv1, upconv1, inter_channels=32)
    concat1 = layers.concatenate([upconv1, attn1])
    conv6 = layers.Conv2D(64, (3, 3), activation='relu', padding='same')(concat1)
    conv6 = layers.Conv2D(64, (3, 3), activation='relu', padding='same')
0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_145 (Conv2D)       │ (None, 128, 128, 128)  │        147,584 │ conv2d_144[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose_29       │ (None, 256, 256, 64)   │         32,832 │ conv2d_145[0][0]       │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_146 (Conv2D)       │ (None, 256, 256, 32)   │          2,080 │ conv2d_129[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_147 (Conv2D)       │ (None, 256, 256, 32)   │          2,080 │ conv2d_transpose_29[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_2 (Add)               │ (None, 256, 256, 32)   │              0 │ conv2d_146[0][0],      │
# │                           │                        │                │ conv2d_147[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_112            │ (None, 256, 256, 32)   │              0 │ add_2[0][0]            │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_148 (Conv2D)       │ (None, 256, 256, 1)    │             33 │ activation_112[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_113            │ (None, 256, 256, 1)    │              0 │ conv2d_148[0][0]       │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multiply_2 (Multiply)     │ (None, 256, 256, 64)   │              0 │ conv2d_129[0][0],      │
# │                           │                        │                │ activation_113[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_29            │ (None, 256, 256, 128)  │              0 │ conv2d_transpose_29[0… │
# │ (Concatenate)             │                        │                │ multiply_2[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_149 (Conv2D)       │ (None, 256, 256, 64)   │         73,792 │ concatenate_29[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_150 (Conv2D)       │ (None, 256, 256, 64)   │         36,928 │ conv2d_149[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_average_pooling2d… │ (None, 64)             │              0 │ conv2d_150[0][0]       │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_1 (Dense)           │ (None, 4)              │            260 │ global_average_poolin… │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 7,784,231 (29.69 MB)
#  Trainable params: 7,784,231 (29.69 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
history = model.fit(
    train_gen_new,  
    epochs=5,
    batch_size=16,
    validation_data=valid_gen_new,  
    steps_per_epoch=train_gen_new.samples // train_gen_new.batch_size,
    validation_steps=valid_gen_new.samples // valid_gen_new.batch_size,
    verbose=1
)
# Out:
# Epoch 1/5
# 854/854 ━━━━━━━━━━━━━━━━━━━━ 660s 756ms/step - accuracy: 0.3953 - loss: 1.3157 - val_accuracy: 0.6533 - val_loss: 0.8045
# Epoch 2/5
# 854/854 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.6250 - loss: 0.9226 - val_accuracy: 0.6154 - val_loss: 0.6354
# Epoch 3/5
# 854/854 ━━━━━━━━━━━━━━━━━━━━ 632s 739ms/step - accuracy: 0.6932 - loss: 0.7379 - val_accuracy: 0.7978 - val_loss: 0.5189
# Epoch 4/5
# 854/854 ━━━━━━━━━━━━━━━━━━━━ 1s 231us/step - accuracy: 0.8125 - loss: 0.6124 - val_accuracy: 0.7692 - val_loss: 0.5935
# Epoch 5/5
# 854/854 ━━━━━━━━━━━━━━━━━━━━ 626s 731ms/step - accuracy: 0.8124 - loss: 0.4905 - val_accuracy: 0.8726 - val_loss: 0.3254

# %%
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Model Accuracy')
plt.legend()
plt.show()

plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Model Loss')
plt.legend()
plt.show()

# %%
y_pred_probs = model.predict(test_gen_new)
y_pred = np.argmax(y_pred_probs, axis=1)
# Out:
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 28s 257ms/step

# %%
y_true = test_gen_new.classes

# %%
cm = confusion_matrix(y_true, y_pred)

plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=test_gen_new.class_indices.keys(), yticklabels=test_gen_new.class_indices.keys())
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()

# %%
report = classification_report(y_true, y_pred, target_names=test_gen_new.class_indices.keys())
print("Classification Report:\n", report)
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.88      0.94      0.91       427
#            1       0.81      0.90      0.85       427
#            2       0.92      0.78      0.84       428
#            3       0.97      0.92      0.94       428
#
#     accuracy                           0.89      1710
#    macro avg       0.89      0.89      0.89      1710
# weighted avg       0.89      0.89      0.89      1710
